# %%
####################################################################################
### Source code by Lauren Hayward Sierens and Juan Carrasquilla
### Code adapted by Matt Richards
### This code builds a simple data set of spirals with K branches and then implements
### and trains a simple feedforward neural network to classify its branches.
######################################################################################

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import random
import math

#Specify font sizes for plots:
plt.rcParams['axes.labelsize']  = 10
plt.rcParams['legend.fontsize'] = 10
plt.rcParams['xtick.labelsize'] = 8
plt.rcParams['ytick.labelsize'] = 8


seed=1234#random.randint(1,2000)#1234
np.random.seed(seed)
tf.set_random_seed(seed)

plt.ion() # turn on interactive mode (for plotting)

############################################################################
####################### CREATE AND PLOT THE DATA SET #######################
############################################################################

N = 50 # number of points per branch
K = 3  # number of branches

N_train = N*K # total number of points in the training set
x_train = np.zeros((N_train,2)) # matrix containing the 2-dimensional datapoints
y_train = np.zeros(N_train, dtype='uint8') # labels (not in one-hot representation)

#print(x_train)

mag_noise = 0.3  # controls how much noise gets added to the data
dTheta    = 4    # difference in theta in each branch

### Data generation: ###
#np.linspace(xo,xf,N) generates numbers between xo and xf in N steps
for j in range(K):
  ix = range(N*j,N*(j+1))
  r = np.linspace(0.01,1,N) # radius
  t = np.linspace(j*(2*np.pi)/K,j*(2*np.pi)/K + dTheta,N) + np.random.randn(N)*mag_noise # theta
#For theta we are determining the angle at which each data point, within the branch leaves the center.
#As an example, for j=1, theta is in between 2pi/3 and 2pi/3+4 and there are N points evenly distrbuted between these two bounds.
#There is a random fluctuation being added to each angle.
  x_train[ix] = np.c_[r*np.cos(t), r*np.sin(t)]
#Defining the training set in its x and y components
  y_train[ix] = j

### Plot the data set: ###
fig = plt.figure(1, figsize=(5,5))
plt.scatter(x_train[:, 0], x_train[:, 1], c=y_train, s=40)#, cmap=plt.cm.Spectral)
plt.xlim([-1,1])
plt.ylim([-1,1])
plt.xlabel('x1')
plt.ylabel('x2')
fig.savefig('spiral_data.pdf')

############################################################################
##################### DEFINE THE NETWORK ARCHITECTURE ######################
############################################################################

### Create placeholders for the input data and labels ###
### (we'll input actual values when we ask TensorFlow to run an actual computation later) ###
x = tf.placeholder(tf.float32, [None, 2]) # input data, tf.placeholder(dtype,shape=None,name=None)
y = tf.placeholder(tf.int32,[None])       # labels
#This is used to allocate the arrays in which we will be using for our data

### Layer 1: ###
###tf.Variable(<initial-value>, name=<optional-name>)
W1 = tf.Variable( tf.random_normal([2, 4], mean=0.0, stddev=0.01, dtype=tf.float32) )
###Here we are defining what numbers will sit in the weight. It will be a 2 by K matrix of random numbers drawn from 
###the normal distribution with mean 0 and sd 0.01.
b1 = tf.Variable( tf.zeros([4]) )
###generating a vector of 3 zeroes
z1 = tf.matmul(x, W1) + b1
###feeding in the input data and biasing each choice by a certain weight which is normally distributed
###tf.matmul does a basic matrix multiplication 
a1 = tf.nn.sigmoid( z1 )
###activation function used here is a sigmoid function

#a1 = tf.nn.relu( z1 )
### activation function used here is a rectified linear unit

### Layer 2 ####
W2 = tf.Variable( tf.random_normal([4, K], mean=0.0, stddev=0.01, dtype=tf.float32) )
#redefining the matrix sizes for these weights to reflect the number of neurons in this layer (i.e. 4)
b2 = tf.Variable( tf.zeros([K]) )
z2 = tf.matmul(a1, W2) + b2#inputing output of a1 as x
a2 = tf.nn.sigmoid( z2 )

### Network output: ###
aL = a2

### Cost function: ###
### (measures how far off our model is from the labels) ###
y_onehot = tf.one_hot(y,depth=K) # labels are converted to one-hot representation
### This one hot representation is just a way to represent the branch number in a mathematical form s.t. the final output
### will be a vector i.e. y_j^l=sigma(x^{l-1}_iW^l_{i,j}+b^l_j)
eps=0.0000000001 # to prevent the logs from diverging
cross_entropy = tf.reduce_mean(-tf.reduce_sum( y_onehot * tf.log(aL+eps) +  (1.0-y_onehot )*tf.log(1.0-aL +eps) , reduction_indices=[1]))
mean_squared = 0.5*tf.reduce_mean(tf.reduce_sum((aL-y_onehot)**2, reduction_indices=[1]))
cost_func = mean_squared#cross_entropy#

### Use backpropagation to minimize the cost function using the gradient descent algorithm: ###
learning_rate  = 0.5 # hyperparameter
train_step = tf.train.GradientDescentOptimizer(learning_rate).minimize(cost_func)

N_epochs = 40000 # number of times to run gradient descent

##############################################################################
################################## TRAINING ##################################
##############################################################################
sess = tf.Session()
sess.run(tf.global_variables_initializer())

epoch_list    = []
cost_training = []
acc_training  = []

############ Function for plotting: ############
def updatePlot():

    ### Generate coordinates covering the whole plane: ###
    padding = 0.1
    spacing = 0.02
    x1_min, x1_max = x_train[:, 0].min() - padding, x_train[:, 0].max() + padding
    x2_min, x2_max = x_train[:, 1].min() - padding, x_train[:, 1].max() + padding
    x1_grid, x2_grid = np.meshgrid(np.arange(x1_min, x1_max, spacing),
                         np.arange(x2_min, x2_max, spacing))

    NN_output       = sess.run(aL,feed_dict={x:np.c_[x1_grid.ravel(), x2_grid.ravel()]})
    predicted_class = np.argmax(NN_output, axis=1)

    ### Plot the classifier: ###
    plt.subplot(121)
    plt.contourf(x1_grid, x2_grid, predicted_class.reshape(x1_grid.shape), K, alpha=0.8)
    plt.scatter(x_train[:, 0], x_train[:, 1], c=y_train, s=40)
    plt.xlim(x1_grid.min(), x1_grid.max())
    plt.ylim(x2_grid.min(), x2_grid.max())
    plt.xlabel('x1')
    plt.ylabel('x2')

    ### Plot the cost function during training: ###
    plt.subplot(222)
    plt.plot(epoch_list,cost_training,'o-')
    plt.xlabel('Epoch')
    plt.ylabel('Training cost')

    ### Plot the training accuracy: ###
    plt.subplot(224)
    plt.plot(epoch_list,acc_training,'o-')
    plt.xlabel('Epoch')
    plt.ylabel('Training accuracy')
############ End of plotting function ############

### Train for several epochs: ###
for epoch in range(N_epochs):
    sess.run(train_step, feed_dict={x: x_train,y:y_train}) #run gradient descent
    
    ### Update the plot and print results every 500 epochs: ###
    if epoch % 500 == 0:
        cost = sess.run(cost_func,feed_dict={x:x_train, y:y_train})
        NN_output = sess.run(aL,feed_dict={x:x_train, y:y_train})
        predicted_class = np.argmax(NN_output, axis=1)
        accuracy = np.mean(predicted_class == y_train)
    
        print( "Iteration %d:\n  Training cost %f\n  Training accuracy %f\n" % (epoch, cost, accuracy) )
    
        epoch_list.append(epoch)
        cost_training.append(cost)
        acc_training.append(accuracy)
        
        ### Update the plot of the resulting classifier: ###
        fig = plt.figure(2,figsize=(10,5))
        fig.subplots_adjust(hspace=.3,wspace=.3)
        plt.clf()
        updatePlot()
        plt.pause(0.1)

plt.savefig('spiral_results.pdf') # Save the figure showing the results in the current directory

plt.show()
# Out:
# Iteration 0:
#   Training cost 0.369281
#   Training accuracy 0.333333
# Iteration 500:
#   Training cost 0.333302
#   Training accuracy 0.333333
# Iteration 1000:
#   Training cost 0.332556
#   Training accuracy 0.466667
# Iteration 1500:
#   Training cost 0.319185
#   Training accuracy 0.433333
# Iteration 2000:
#   Training cost 0.287950
#   Training accuracy 0.486667
# Iteration 2500:
#   Training cost 0.258369
#   Training accuracy 0.513333
# Iteration 3000:
#   Training cost 0.245810
#   Training accuracy 0.500000
# Iteration 3500:
#   Training cost 0.241510
#   Training accuracy 0.500000
# Iteration 4000:
#   Training cost 0.238872
#   Training accuracy 0.506667
# Iteration 4500:
#   Training cost 0.236902
#   Training accuracy 0.513333
# Iteration 5000:
#   Training cost 0.235241
#   Training accuracy 0.513333
# Iteration 5500:
#   Training cost 0.233704
#   Training accuracy 0.493333
# Iteration 6000:
#   Training cost 0.232172
#   Training accuracy 0.493333
# Iteration 6500:
#   Training cost 0.230541
#   Training accuracy 0.493333
# Iteration 7000:
#   Training cost 0.228671
#   Training accuracy 0.493333
# Iteration 7500:
#   Training cost 0.226318
#   Training accuracy 0.500000
# Iteration 8000:
#   Training cost 0.222968
#   Training accuracy 0.513333
# Iteration 8500:
#   Training cost 0.217474
#   Training accuracy 0.566667
# Iteration 9000:
#   Training cost 0.208372
#   Training accuracy 0.653333
# Iteration 9500:
#   Training cost 0.197111
#   Training accuracy 0.713333
# Iteration 10000:
#   Training cost 0.186880
#   Training accuracy 0.753333
# Iteration 10500:
#   Training cost 0.178542
#   Training accuracy 0.773333
# Iteration 11000:
#   Training cost 0.171833
#   Training accuracy 0.773333
# Iteration 11500:
#   Training cost 0.166315
#   Training accuracy 0.793333
# Iteration 12000:
#   Training cost 0.161625
#   Training accuracy 0.786667
# Iteration 12500:
#   Training cost 0.157509
#   Training accuracy 0.793333
# Iteration 13000:
#   Training cost 0.153807
#   Training accuracy 0.800000
# Iteration 13500:
#   Training cost 0.150414
#   Training accuracy 0.793333
# Iteration 14000:
#   Training cost 0.147253
#   Training accuracy 0.800000
# Iteration 14500:
#   Training cost 0.144265
#   Training accuracy 0.793333
# Iteration 15000:
#   Training cost 0.141406
#   Training accuracy 0.793333
# Iteration 15500:
#   Training cost 0.138644
#   Training accuracy 0.806667
# Iteration 16000:
#   Training cost 0.135964
#   Training accuracy 0.820000
# Iteration 16500:
#   Training cost 0.133361
#   Training accuracy 0.826667
# Iteration 17000:
#   Training cost 0.130843
#   Training accuracy 0.833333
# Iteration 17500:
#   Training cost 0.128418
#   Training accuracy 0.840000
# Iteration 18000:
#   Training cost 0.126097
#   Training accuracy 0.846667
# Iteration 18500:
#   Training cost 0.123888
#   Training accuracy 0.853333
# Iteration 19000:
#   Training cost 0.121798
#   Training accuracy 0.853333
# Iteration 19500:
#   Training cost 0.119827
#   Training accuracy 0.866667
# Iteration 20000:
#   Training cost 0.117974
#   Training accuracy 0.873333
# Iteration 20500:
#   Training cost 0.116237
#   Training accuracy 0.873333
# Iteration 21000:
#   Training cost 0.114609
#   Training accuracy 0.893333
# Iteration 21500:
#   Training cost 0.113084
#   Training accuracy 0.893333
# Iteration 22000:
#   Training cost 0.111656
#   Training accuracy 0.893333
# Iteration 22500:
#   Training cost 0.110316
#   Training accuracy 0.893333
# Iteration 23000:
#   Training cost 0.109057
#   Training accuracy 0.893333
# Iteration 23500:
#   Training cost 0.107874
#   Training accuracy 0.900000
# Iteration 24000:
#   Training cost 0.106758
#   Training accuracy 0.900000
# Iteration 24500:
#   Training cost 0.105704
#   Training accuracy 0.900000
# Iteration 25000:
#   Training cost 0.104708
#   Training accuracy 0.900000
# Iteration 25500:
#   Training cost 0.103765
#   Training accuracy 0.900000
# Iteration 26000:
#   Training cost 0.102870
#   Training accuracy 0.900000
# Iteration 26500:
#   Training cost 0.102021
#   Training accuracy 0.900000
# Iteration 27000:
#   Training cost 0.101214
#   Training accuracy 0.900000
# Iteration 27500:
#   Training cost 0.100447
#   Training accuracy 0.900000
# Iteration 28000:
#   Training cost 0.099717
#   Training accuracy 0.900000
# Iteration 28500:
#   Training cost 0.099022
#   Training accuracy 0.900000
# Iteration 29000:
#   Training cost 0.098359
#   Training accuracy 0.900000
# Iteration 29500:
#   Training cost 0.097727
#   Training accuracy 0.900000
# Iteration 30000:
#   Training cost 0.097124
#   Training accuracy 0.900000
# Iteration 30500:
#   Training cost 0.096548
#   Training accuracy 0.906667
# Iteration 31000:
#   Training cost 0.095997
#   Training accuracy 0.906667
# Iteration 31500:
#   Training cost 0.095469
#   Training accuracy 0.913333
# Iteration 32000:
#   Training cost 0.094965
#   Training accuracy 0.913333
# Iteration 32500:
#   Training cost 0.094481
#   Training accuracy 0.913333
# Iteration 33000:
#   Training cost 0.094017
#   Training accuracy 0.913333
# Iteration 33500:
#   Training cost 0.093571
#   Training accuracy 0.913333
# Iteration 34000:
#   Training cost 0.093144
#   Training accuracy 0.913333
# Iteration 34500:
#   Training cost 0.092733
#   Training accuracy 0.913333
# Iteration 35000:
#   Training cost 0.092338
#   Training accuracy 0.913333
# Iteration 35500:
#   Training cost 0.091958
#   Training accuracy 0.913333
# Iteration 36000:
#   Training cost 0.091593
#   Training accuracy 0.913333
# Iteration 36500:
#   Training cost 0.091240
#   Training accuracy 0.913333
# Iteration 37000:
#   Training cost 0.090901
#   Training accuracy 0.913333
# Iteration 37500:
#   Training cost 0.090574
#   Training accuracy 0.913333
# Iteration 38000:
#   Training cost 0.090258
#   Training accuracy 0.913333
# Iteration 38500:
#   Training cost 0.089953
#   Training accuracy 0.913333
# Iteration 39000:
#   Training cost 0.089659
#   Training accuracy 0.913333
# Iteration 39500:
#   Training cost 0.089375
#   Training accuracy 0.913333
